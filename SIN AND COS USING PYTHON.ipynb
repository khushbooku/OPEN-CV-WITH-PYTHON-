# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 5* np.pi, 0.5)  
y = np.cos(x) 
plt.title("cose wave form")
# Out:
# Text(0.5, 1.0, 'cose wave form')

# %%
#Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 5* np.pi, 0.5)  
y = np.cos(x) 
plt.title("cose wave form")
# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()
